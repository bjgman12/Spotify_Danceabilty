# %% [markdown]
# <a href="https://colab.research.google.com/github/bjgman12/Spotify_Danceabilty/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
drive.mount( '/content/drive', force_remount=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Spotify Data

# %%
spotify = pd.read_csv('data_by_year.csv')
spotify.head()
# Out:
#    mode  year  acousticness  ...   valence  popularity  key
# 0     1  1921      0.886896  ...  0.379327    0.653333    2
# 1     1  1922      0.938592  ...  0.535549    0.140845   10
# 2     1  1923      0.957247  ...  0.625492    5.389189    0
# 3     1  1924      0.940200  ...  0.663725    0.661017   10
# 4     1  1925      0.962607  ...  0.621929    2.604317    5
#
# [5 rows x 14 columns]

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   mode              100 non-null    int64
#  1   year              100 non-null    int64
#  2   acousticness      100 non-null    float64
#  3   danceability      100 non-null    float64
#  4   duration_ms       100 non-null    float64
#  5   energy            100 non-null    float64
#  6   instrumentalness  100 non-null    float64
#  7   liveness          100 non-null    float64
#  8   loudness          100 non-null    float64
#  9   speechiness       100 non-null    float64
#  10  tempo             100 non-null    float64
#  11  valence           100 non-null    float64
#  12  popularity        100 non-null    float64
#  13  key               100 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 11.1 KB

# %%
x = spotify['year'].values

y = spotify['danceability'].values

# %% [markdown]
# # Range of years

# %%
x
# Out:
# array([1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931,
#        1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942,
#        1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953,
#        1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#        1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#        1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020])

# %%
x = x.reshape(-1,1)

# %%
# x feat = year
# y feat = dancability
x_train, x_test , y_train, y_test = train_test_split(x,y, train_size = .8 , test_size =.2,random_state=100)

# %%
plt.scatter(x_train,y_train, color ='red')
plt.xlabel('Year Published')
plt.ylabel('Dacibility')
plt.title('Training Data')
# Out:
# Text(0.5, 1.0, 'Training Data')

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
y_predict = lm.predict(x_test)
print(f'Train Accuracy {round(lm.score(x_train,y_train)* 100,2)}%')
print(f'Test Accuracy {round(lm.score(x_test,y_test) * 100,2)}%')
# Out:
# Train Accuracy 23.2%
# Test Accuracy 23.34%

# %%
plt.scatter(x_train,y_train,color= "red")
plt.plot(x_test, y_predict)
plt.xlabel("Year Published")
plt.ylabel("Dancibility")
plt.title('Trained Model Plot')
plt.plot
# Out:
# <function matplotlib.pyplot.plot>

# %%
import seaborn as sns

# %%
sns.set()
plt.figure(figsize=(10,6), dpi=300)
sns.regplot(x='year', y='danceability',data=spotify)

# %% [markdown]
# # Conclusions that can be made from regression model

# %% [markdown]
# - Music has become more deanceable over time
# - outliers suggest that there was a spike in daceability in the 1930s
# - outliers suggest that there was a drop in the 1950s
